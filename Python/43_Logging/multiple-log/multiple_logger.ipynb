# %%
import logging

#Create a logger for module 1
logger1=logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

#Create a logger for module 2
logger2=logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

#config
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
    )

# %%
#log message with different loggers
logger1.debug("this is debug message for module1")
logger2.warning("this is warning message for module2")
logger2.error("this is an error message")
# Out:
# 2026-03-02 19:17:41-module1-DEBUG-this is debug message for module1
# 2026-03-02 19:17:41-module2-WARNING-this is warning message for module2
# 2026-03-02 19:17:41-module2-ERROR-this is an error message
