# %% [markdown]
#  # Multithreading with Thread Pool Exector

# %%
from concurrent.futures import ThreadPoolExecutor
import time

# %%
def print_number(num):
    time.sleep(1)
    return f"Number: {num}"

num=[1,2,3,4,5,6,7,8,9]

t=time.time()

with ThreadPoolExecutor(max_workers=3) as executor:
    results=executor.map(print_number,num)

for result in results:
    print(result)

finished_time=time.time()-t
print(finished_time)
# Out:
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Number: 5
# Number: 6
# Number: 7
# Number: 8
# Number: 9
# 3.0051255226135254
